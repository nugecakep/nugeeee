# %% [markdown]
# <a href="https://colab.research.google.com/github/nugecakep/nugeeee/blob/ALIN/rgbalinNEW123.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NUGE

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
img_path = "nuge.jpeg"
img = cv2.imread(img_path)
print(img.shape)
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)
R, G, B = fix_img[:,:,0], fix_img[:,:,1], fix_img[:,:,2]
print(np.array(fix_img))
# Out:
# (1156, 867, 3)
# [[[132 125 133]
#   [152 145 153]
#   [130 123 131]
#   ...
#   [159 154 158]
#   [150 145 149]
#   [142 137 141]]
#
#  [[129 122 130]
#   [117 110 118]
#   [122 115 123]
#   ...
#   [153 148 152]
#   [145 140 144]
#   [139 134 138]]
#
#  [[143 136 144]
#   [117 110 118]
#   [127 120 128]
#   ...
#   [156 151 155]
#   [149 144 148]
#   [144 139 143]]
#
#  ...
#
#  [[121 120 128]
#   [121 120 128]
#   [122 121 129]
#   ...
#   [107 100 107]
#   [122 115 122]
#   [128 121 128]]
#
#  [[118 117 125]
#   [118 117 125]
#   [119 118 126]
#   ...
#   [115 108 115]
#   [127 120 127]
#   [130 123 130]]
#
#  [[115 114 122]
#   [115 114 122]
#   [116 115 123]
#   ...
#   [111 104 111]
#   [121 114 121]
#   [120 113 120]]]

# %% [markdown]
# METODE LIGHTNESS NUGE

# %%
#metode lightness
fix_img[:] = np.max(fix_img, axis = -1, keepdims=1)/2 + np.min(fix_img, axis = -1, keepdims=1)/2
print(np.array(fix_img[:]))
plt.axis("off")
plt.imshow(fix_img[:])
plt.savefig("Metode Lightness NUGE", bbox_inches="tight")
# Out:
# [[[129 129 129]
#   [149 149 149]
#   [127 127 127]
#   ...
#   [156 156 156]
#   [147 147 147]
#   [139 139 139]]
#
#  [[126 126 126]
#   [114 114 114]
#   [119 119 119]
#   ...
#   [150 150 150]
#   [142 142 142]
#   [136 136 136]]
#
#  [[140 140 140]
#   [114 114 114]
#   [124 124 124]
#   ...
#   [153 153 153]
#   [146 146 146]
#   [141 141 141]]
#
#  ...
#
#  [[124 124 124]
#   [124 124 124]
#   [125 125 125]
#   ...
#   [103 103 103]
#   [118 118 118]
#   [124 124 124]]
#
#  [[121 121 121]
#   [121 121 121]
#   [122 122 122]
#   ...
#   [111 111 111]
#   [123 123 123]
#   [126 126 126]]
#
#  [[118 118 118]
#   [118 118 118]
#   [119 119 119]
#   ...
#   [107 107 107]
#   [117 117 117]
#   [116 116 116]]]

# %% [markdown]
# METODE AVERAGE NUGE

# %%
gray_img = np.mean(fix_img, axis = -1)
print(np.array(gray_img))
plt.axis("off")
plt.imshow(gray_img, cmap = "gray")
plt.savefig("Metode Average NUGE", bbox_inches="tight")
# Out:
# [[129. 149. 127. ... 156. 147. 139.]
#  [126. 114. 119. ... 150. 142. 136.]
#  [140. 114. 124. ... 153. 146. 141.]
#  ...
#  [124. 124. 125. ... 103. 118. 124.]
#  [121. 121. 122. ... 111. 123. 126.]
#  [118. 118. 119. ... 107. 117. 116.]]

# %% [markdown]
# Metode Luminosity/Weighted Average NUGE

# %%
lumi_img = (0.2126*R) + (0.7152*G) + (0.0722*B)
print(lumi_img)
print(np.array(lumi_img))
plt.axis("off")
plt.imshow(lumi_img, cmap ="gray")
plt.savefig("Metode Luminosity NUGE", bbox_inches="tight")
# Out:
# [[129. 149. 127. ... 156. 147. 139.]
#  [126. 114. 119. ... 150. 142. 136.]
#  [140. 114. 124. ... 153. 146. 141.]
#  ...
#  [124. 124. 125. ... 103. 118. 124.]
#  [121. 121. 122. ... 111. 123. 126.]
#  [118. 118. 119. ... 107. 117. 116.]]
# [[129. 149. 127. ... 156. 147. 139.]
#  [126. 114. 119. ... 150. 142. 136.]
#  [140. 114. 124. ... 153. 146. 141.]
#  ...
#  [124. 124. 125. ... 103. 118. 124.]
#  [121. 121. 122. ... 111. 123. 126.]
#  [118. 118. 119. ... 107. 117. 116.]]

# %% [markdown]
# Metode Weighted Average/Luminosity

# %%
wav_img = (0.299*R) + (0.587*G) + (0.114*B)
# print(lumi_img)
print(np.array(wav_img))
plt.axis("off")
plt.imshow(wav_img, cmap = "gray")
plt.savefig("Metode Weighted Average NUGE", bbox_inches="tight")
# Out:
# [[129. 149. 127. ... 156. 147. 139.]
#  [126. 114. 119. ... 150. 142. 136.]
#  [140. 114. 124. ... 153. 146. 141.]
#  ...
#  [124. 124. 125. ... 103. 118. 124.]
#  [121. 121. 122. ... 111. 123. 126.]
#  [118. 118. 119. ... 107. 117. 116.]]

# %% [markdown]
# JIAN

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
img_path = "jian.jpeg"
img = cv2.imread(img_path)
print(img.shape)
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)
R, G, B = fix_img[:,:,0], fix_img[:,:,1], fix_img[:,:,2]
print(np.array(fix_img))
# Out:
# (4032, 3024, 3)
# [[[ 79 109 145]
#   [ 79 109 145]
#   [ 79 109 145]
#   ...
#   [ 90 119 149]
#   [ 90 119 149]
#   [ 90 119 149]]
#
#  [[ 79 109 145]
#   [ 79 109 145]
#   [ 79 109 145]
#   ...
#   [ 90 119 149]
#   [ 90 119 149]
#   [ 90 119 149]]
#
#  [[ 79 109 145]
#   [ 79 109 145]
#   [ 79 109 145]
#   ...
#   [ 90 119 149]
#   [ 90 119 149]
#   [ 90 119 149]]
#
#  ...
#
#  [[ 77  98 119]
#   [ 80 101 122]
#   [ 86 107 128]
#   ...
#   [ 16  32  45]
#   [ 16  32  45]
#   [ 16  32  45]]
#
#  [[ 87 108 129]
#   [ 89 110 131]
#   [ 92 113 134]
#   ...
#   [ 16  32  45]
#   [ 15  31  44]
#   [ 15  31  44]]
#
#  [[104 125 146]
#   [104 125 146]
#   [104 125 146]
#   ...
#   [ 16  32  45]
#   [ 15  31  44]
#   [ 14  30  43]]]

# %% [markdown]
# METODE LIGHTNESS JIAN

# %%
fix_img[:] = np.max(fix_img, axis = -1, keepdims=1)/2 + np.min(fix_img, axis = -1, keepdims=1)/2
print(np.array(fix_img[:]))
plt.axis("off")
plt.imshow(fix_img[:])
plt.savefig("Metode Lightness JIAN", bbox_inches="tight")
# Out:
# [[[112 112 112]
#   [112 112 112]
#   [112 112 112]
#   ...
#   [119 119 119]
#   [119 119 119]
#   [119 119 119]]
#
#  [[112 112 112]
#   [112 112 112]
#   [112 112 112]
#   ...
#   [119 119 119]
#   [119 119 119]
#   [119 119 119]]
#
#  [[112 112 112]
#   [112 112 112]
#   [112 112 112]
#   ...
#   [119 119 119]
#   [119 119 119]
#   [119 119 119]]
#
#  ...
#
#  [[ 98  98  98]
#   [101 101 101]
#   [107 107 107]
#   ...
#   [ 30  30  30]
#   [ 30  30  30]
#   [ 30  30  30]]
#
#  [[108 108 108]
#   [110 110 110]
#   [113 113 113]
#   ...
#   [ 30  30  30]
#   [ 29  29  29]
#   [ 29  29  29]]
#
#  [[125 125 125]
#   [125 125 125]
#   [125 125 125]
#   ...
#   [ 30  30  30]
#   [ 29  29  29]
#   [ 28  28  28]]]

# %% [markdown]
# METODE AVERAGE JIAN

# %%
gray_img = np.mean(fix_img, axis = -1)
print(np.array(gray_img))
plt.axis("off")
plt.imshow(gray_img, cmap = "gray")
plt.savefig("Metode Average JIAN", bbox_inches="tight")
# Out:
# [[112. 112. 112. ... 119. 119. 119.]
#  [112. 112. 112. ... 119. 119. 119.]
#  [112. 112. 112. ... 119. 119. 119.]
#  ...
#  [ 98. 101. 107. ...  30.  30.  30.]
#  [108. 110. 113. ...  30.  29.  29.]
#  [125. 125. 125. ...  30.  29.  28.]]

# %% [markdown]
# Metode Luminosity/Weighted Average JIAN

# %%
lumi_img = (0.2126*R) + (0.7152*G) + (0.0722*B)
print(lumi_img)
print(np.array(lumi_img))
plt.axis("off")
plt.imshow(lumi_img, cmap ="gray")
plt.savefig("Metode Luminosity JIAN", bbox_inches="tight")
# Out:
# [[112. 112. 112. ... 119. 119. 119.]
#  [112. 112. 112. ... 119. 119. 119.]
#  [112. 112. 112. ... 119. 119. 119.]
#  ...
#  [ 98. 101. 107. ...  30.  30.  30.]
#  [108. 110. 113. ...  30.  29.  29.]
#  [125. 125. 125. ...  30.  29.  28.]]
# [[112. 112. 112. ... 119. 119. 119.]
#  [112. 112. 112. ... 119. 119. 119.]
#  [112. 112. 112. ... 119. 119. 119.]
#  ...
#  [ 98. 101. 107. ...  30.  30.  30.]
#  [108. 110. 113. ...  30.  29.  29.]
#  [125. 125. 125. ...  30.  29.  28.]]

# %% [markdown]
# Metode Weighted Average/Luminosity

# %%
wav_img = (0.299*R) + (0.587*G) + (0.114*B)
# print(lumi_img)
print(np.array(wav_img))
plt.axis("off")
plt.imshow(wav_img, cmap = "gray")
plt.savefig("Metode Weighted Average JIAN", bbox_inches="tight")
# Out:
# [[112. 112. 112. ... 119. 119. 119.]
#  [112. 112. 112. ... 119. 119. 119.]
#  [112. 112. 112. ... 119. 119. 119.]
#  ...
#  [ 98. 101. 107. ...  30.  30.  30.]
#  [108. 110. 113. ...  30.  29.  29.]
#  [125. 125. 125. ...  30.  29.  28.]]

# %% [markdown]
# ARIL

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
img_path = "aril.jpeg"
img = cv2.imread(img_path)
print(img.shape)
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)
R, G, B = fix_img[:,:,0], fix_img[:,:,1], fix_img[:,:,2]
print(np.array(fix_img))
# Out:
# (3264, 2176, 3)
# [[[112 129 139]
#   [112 129 139]
#   [111 128 138]
#   ...
#   [141 137 134]
#   [141 137 134]
#   [141 137 134]]
#
#  [[111 128 138]
#   [111 128 138]
#   [111 128 138]
#   ...
#   [141 137 134]
#   [141 137 134]
#   [141 137 134]]
#
#  [[110 127 137]
#   [109 126 136]
#   [109 126 136]
#   ...
#   [141 137 134]
#   [141 137 134]
#   [141 137 134]]
#
#  ...
#
#  [[120 111  94]
#   [120 111  94]
#   [120 111  94]
#   ...
#   [ 48  33  28]
#   [ 48  33  28]
#   [ 47  32  27]]
#
#  [[120 111  94]
#   [120 111  94]
#   [120 111  94]
#   ...
#   [ 48  33  28]
#   [ 48  33  28]
#   [ 48  33  28]]
#
#  [[120 111  94]
#   [120 111  94]
#   [120 111  94]
#   ...
#   [ 49  34  29]
#   [ 48  33  28]
#   [ 48  33  28]]]

# %% [markdown]
# METODE LIGHTNESS

# %%
fix_img[:] = np.max(fix_img, axis = -1, keepdims=1)/2 + np.min(fix_img, axis = -1, keepdims=1)/2
print(np.array(fix_img[:]))
plt.axis("off")
plt.imshow(fix_img[:])
plt.savefig("Metode Lightness ARIL", bbox_inches="tight")
# Out:
# [[[125 125 125]
#   [125 125 125]
#   [124 124 124]
#   ...
#   [137 137 137]
#   [137 137 137]
#   [137 137 137]]
#
#  [[124 124 124]
#   [124 124 124]
#   [124 124 124]
#   ...
#   [137 137 137]
#   [137 137 137]
#   [137 137 137]]
#
#  [[123 123 123]
#   [122 122 122]
#   [122 122 122]
#   ...
#   [137 137 137]
#   [137 137 137]
#   [137 137 137]]
#
#  ...
#
#  [[107 107 107]
#   [107 107 107]
#   [107 107 107]
#   ...
#   [ 38  38  38]
#   [ 38  38  38]
#   [ 37  37  37]]
#
#  [[107 107 107]
#   [107 107 107]
#   [107 107 107]
#   ...
#   [ 38  38  38]
#   [ 38  38  38]
#   [ 38  38  38]]
#
#  [[107 107 107]
#   [107 107 107]
#   [107 107 107]
#   ...
#   [ 39  39  39]
#   [ 38  38  38]
#   [ 38  38  38]]]

# %% [markdown]
# METODE AVERAGE ARIL

# %%
gray_img = np.mean(fix_img, axis = -1)
print(np.array(gray_img))
plt.axis("off")
plt.imshow(gray_img, cmap = "gray")
plt.savefig("Metode Average ARIL", bbox_inches="tight")
# Out:
# [[125. 125. 124. ... 137. 137. 137.]
#  [124. 124. 124. ... 137. 137. 137.]
#  [123. 122. 122. ... 137. 137. 137.]
#  ...
#  [107. 107. 107. ...  38.  38.  37.]
#  [107. 107. 107. ...  38.  38.  38.]
#  [107. 107. 107. ...  39.  38.  38.]]

# %% [markdown]
# Metode Luminosity ARIL

# %%
lumi_img = (0.2126*R) + (0.7152*G) + (0.0722*B)
print(lumi_img)
print(np.array(lumi_img))
plt.axis("off")
plt.imshow(lumi_img, cmap ="gray")
plt.savefig("Metode Luminosity ARIL", bbox_inches="tight")
# Out:
# [[125. 125. 124. ... 137. 137. 137.]
#  [124. 124. 124. ... 137. 137. 137.]
#  [123. 122. 122. ... 137. 137. 137.]
#  ...
#  [107. 107. 107. ...  38.  38.  37.]
#  [107. 107. 107. ...  38.  38.  38.]
#  [107. 107. 107. ...  39.  38.  38.]]
# [[125. 125. 124. ... 137. 137. 137.]
#  [124. 124. 124. ... 137. 137. 137.]
#  [123. 122. 122. ... 137. 137. 137.]
#  ...
#  [107. 107. 107. ...  38.  38.  37.]
#  [107. 107. 107. ...  38.  38.  38.]
#  [107. 107. 107. ...  39.  38.  38.]]

# %% [markdown]
# Metode Weighted Average/Luminosity

# %%
wav_img = (0.299*R) + (0.587*G) + (0.114*B)
# print(lumi_img)
print(np.array(wav_img))
plt.axis("off")
plt.imshow(wav_img, cmap = "gray")
plt.savefig("Metode Weighted Average ARIL", bbox_inches="tight")
# Out:
# [[125. 125. 124. ... 137. 137. 137.]
#  [124. 124. 124. ... 137. 137. 137.]
#  [123. 122. 122. ... 137. 137. 137.]
#  ...
#  [107. 107. 107. ...  38.  38.  37.]
#  [107. 107. 107. ...  38.  38.  38.]
#  [107. 107. 107. ...  39.  38.  38.]]

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

def convert_to_grayscale(image):
    # Menggunakan formula konversi warna ke citra grayscale
    grayscale_image = 0.299 * image[:,:,2] + 0.587 * image[:,:,1] + 0.114 * image[:,:,0]
    return grayscale_image

# Membaca citra
nuge = cv2.imread('nuge.jpeg')
jian = cv2.imread('jian.jpeg')
aril = cv2.imread('aril.jpeg')

# Memisahkan saluran warna
B_nuge, G_nuge, R_nuge = cv2.split(nuge)
B_jian, G_jian, R_jian = cv2.split(jian)
B_aril, G_aril, R_aril = cv2.split(aril)

# Menghitung citra grayscale dari setiap citra
gray_nuge = convert_to_grayscale(nuge)
gray_jian = convert_to_grayscale(jian)
gray_aril = convert_to_grayscale(aril)

# Menampilkan citra asli dan citra grayscale
plt.figure(figsize=(12, 8))

plt.subplot(3, 4, 1), plt.imshow(B_nuge, cmap='Blues'), plt.title('Blue Nuge')
plt.subplot(3, 4, 2), plt.imshow(G_nuge, cmap='Greens'), plt.title('Green Nuge')
plt.subplot(3, 4, 3), plt.imshow(R_nuge, cmap='Reds'), plt.title('Red Nuge')
plt.subplot(3, 4, 4), plt.imshow(nuge), plt.title('Original Nuge')

plt.subplot(3, 4, 5), plt.imshow(B_jian, cmap='Blues'), plt.title('Blue Jian')
plt.subplot(3, 4, 6), plt.imshow(G_jian, cmap='Greens'), plt.title('Green Jian')
plt.subplot(3, 4, 7), plt.imshow(R_jian, cmap='Reds'), plt.title('Red Jian')
plt.subplot(3, 4, 8), plt.imshow(jian), plt.title('Original Jian')

plt.subplot(3, 4, 9), plt.imshow(B_aril, cmap='Blues'), plt.title('Blue Aril')
plt.subplot(3, 4, 10), plt.imshow(G_aril, cmap='Greens'), plt.title('Green Aril')
plt.subplot(3, 4, 11), plt.imshow(R_aril, cmap='Reds'), plt.title('Red Aril')
plt.subplot(3, 4, 12), plt.imshow(aril), plt.title('Original Aril')

plt.show()
